# %% [markdown]
# ## EXERCISE2
#
# Using bookings file, get TOP10 arrival airports including number of passengers.
# Bonus: Get the name of the city/airport corresponsding to that airport

# %%
pwd
# Out:
# '/Users/cortinas/Documents/DSchallenge/dschallenge'

# %%
# !ls -lrt
# Out:
# total 15510144
# -rw-r--r--@ 1 cortinas  staff         679 11 jun 18:33 README.md
# -rw-r--r--  1 cortinas  staff  4244874509 11 jun 18:54 bookings.csv
# -rw-r--r--  1 cortinas  staff  3696229366 11 jun 18:57 searches.csv
# -rw-r--r--  1 cortinas  staff       22135 11 jun 19:11 exercise1.ipynb
# -rw-r--r--  1 cortinas  staff       22135 11 jun 19:11 exercise1-Copy1.ipynb
# -rw-r--r--  1 cortinas  staff       30817 14 jun 19:27 exercise2.ipynb

# %% [markdown]
# IMPORT LIBRARIES

# %%
#Import libraries to use
import bz2
import pandas as pd

# %% [markdown]
# EXPLORING DATA

# %%
#Data exploratory
bookings = pd.read_csv('bookings.csv', nrows=1000, sep='^')

bookings.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port  ...  route            \
# 0  2013-02-22 00:00:00      1708         0  ZRH       ...  LHRZRH
# 1  2013-03-26 00:00:00    135270         0  SAL       ...  SALATLCLT
# 2  2013-03-26 00:00:00    135270         0  SAL       ...  CLTATLSAL
# 3  2013-03-26 00:00:00     30885         0  AKL       ...  AKLHKGSVO
# 4  2013-03-26 00:00:00     30885         0  AKL       ...  SVOHKGAKL
#
#   carrier  bkg_class  cab_class  brd_time             off_time            pax  \
# 0      VI  T          Y          2013-03-07 08:50:00  2013-03-07 11:33:37  -1
# 1      NV  L          Y          2013-04-12 13:04:00  2013-04-12 22:05:40   1
# 2      NV  U          Y          2013-07-15 07:00:00  2013-07-15 11:34:51   1
# 3      XK  G          Y          2013-04-24 23:59:00  2013-04-25 16:06:31   1
# 4      XK  G          Y          2013-05-14 20:15:00  2013-05-16 10:44:50   1
#
#    year month  oid
# 0  2013     3  NULL
# 1  2013     3  NULL
# 2  2013     3  NULL
# 3  2013     3  SYDA82546
# 4  2013     3  SYDA82546
#
# [5 rows x 38 columns]

# %%
bookings.shape
# Out:
# (1000, 38)

# %%
bookings.columns.tolist()
# Out:
# ['act_date           ',
#  'source',
#  'pos_ctry',
#  'pos_iata',
#  'pos_oid  ',
#  'rloc          ',
#  'cre_date           ',
#  'duration',
#  'distance',
#  'dep_port',
#  'dep_city',
#  'dep_ctry',
#  'arr_port',
#  'arr_city',
#  'arr_ctry',
#  'lst_port',
#  'lst_city',
#  'lst_ctry',
#  'brd_port',
#  'brd_city',
#  'brd_ctry',
#  'off_port',
#  'off_city',
#  'off_ctry',
#  'mkt_port',
#  'mkt_city',
#  'mkt_ctry',
#  'intl',
#  'route          ',
#  'carrier',
#  'bkg_class',
#  'cab_class',
#  'brd_time           ',
#  'off_time           ',
#  'pax',
#  'year',
#  'month',
#  'oid      ']

# %%
bookings.dtypes
# Out:
# act_date               object
# source                 object
# pos_ctry               object
# pos_iata               object
# pos_oid                object
# rloc                   object
# cre_date               object
# duration                int64
# distance                int64
# dep_port               object
# dep_city               object
# dep_ctry               object
# arr_port               object
# arr_city               object
# arr_ctry               object
# lst_port               object
# lst_city               object
# lst_ctry               object
# brd_port               object
# brd_city               object
# brd_ctry               object
# off_port               object
# off_city               object
# off_ctry               object
# mkt_port               object
# mkt_city               object
# mkt_ctry               object
# intl                    int64
# route                  object
# carrier                object
# bkg_class              object
# cab_class              object
# brd_time               object
# off_time               object
# pax                     int64
# year                    int64
# month                   int64
# oid                    object
# dtype: object

# %%
bookings.isnull().sum()
# Out:
# act_date               0
# source                 0
# pos_ctry               0
# pos_iata               0
# pos_oid                0
# rloc                   0
# cre_date               0
# duration               0
# distance               0
# dep_port               0
# dep_city               0
# dep_ctry               0
# arr_port               0
# arr_city               0
# arr_ctry               0
# lst_port               0
# lst_city               0
# lst_ctry               0
# brd_port               0
# brd_city               0
# brd_ctry               0
# off_port               0
# off_city               0
# off_ctry               0
# mkt_port               0
# mkt_city               0
# mkt_ctry               0
# intl                   0
# route                  0
# carrier                0
# bkg_class              0
# cab_class              0
# brd_time               0
# off_time               0
# pax                    0
# year                   0
# month                  0
# oid                    0
# dtype: int64

# %%
bookings.describe()
# Out:
#             duration      distance         intl          pax    year   month
# count    1000.000000   1000.000000  1000.000000  1000.000000  1000.0  1000.0
# mean    23935.433000    407.569000     0.643000     0.532000  2013.0     3.0
# std     54459.101785   1490.087967     0.479355     1.976077     0.0     0.0
# min        61.000000      0.000000     0.000000    -8.000000  2013.0     3.0
# 25%      3493.000000      0.000000     0.000000    -1.000000  2013.0     3.0
# 50%      6891.000000      0.000000     1.000000     1.000000  2013.0     3.0
# 75%     17940.000000      0.000000     1.000000     1.000000  2013.0     3.0
# max    482174.000000  10995.000000     1.000000    21.000000  2013.0     3.0

# %% [markdown]
# FILTERING ONLY REQUIRED COLUMNS

# %%
bookings = pd.read_csv('bookings.csv', nrows=1000, sep='^', usecols=['arr_port', 'pax', 'year'])
bookings= bookings.dropna()
bookings.head()
# Out:
#    arr_port  pax  year
# 0  LHR        -1  2013
# 1  CLT         1  2013
# 2  CLT         1  2013
# 3  SVO         1  2013
# 4  SVO         1  2013

# %% [markdown]
# FILTERING 2013 RECORDS

# %%
bookings2013 = bookings[bookings['year'] == 2013]
bookings2013.drop('year', axis=1, inplace=True)
bookings.head()
# Out:
#    arr_port  pax  year
# 0  LHR        -1  2013
# 1  CLT         1  2013
# 2  CLT         1  2013
# 3  SVO         1  2013
# 4  SVO         1  2013

# %% [markdown]
# GROUPING BY ARRIVAL AIRPORTS, SORT THEM BY PAX SUM, AND GET THE FIRST 10

# %%
arrival_airports =bookings2013.groupby('arr_port')

# %%
arrival_airports.sum()
# Out:
#           pax
# arr_port
# ACC         6
# ADD         2
# AGP         6
# ALA         2
# ALC         4
# ...       ...
# YWG         4
# YXE         1
# YYC         0
# YYZ         2
# ZRH        -1
#
# [201 rows x 1 columns]

# %%
arrival_airports.sum().sort_values('pax', ascending = False).head(10)
# Out:
#           pax
# arr_port
# DCA        50
# JFK        14
# FLL        13
# PVG        13
# CGK        12
# LGA        12
# SVO        12
# LAS        11
# BOS        11
# MIA        11

# %% [markdown]
# ANALYIS AND PROCESS EXECUTED IN A SAMPLE OF N ROWS, NOW SAME PROCESS IMPLEMENTED IN BIG DATA

# %%
bookings = pd.read_csv('bookings.csv', sep='^', usecols =['arr_port', 'pax', 'year'], iterator=True)

# %%
type(bookings)
# Out:
# pandas.io.parsers.TextFileReader

# %%
bookings = pd.read_csv('bookings.csv', sep='^', usecols =['arr_port', 'pax', 'year'], chunksize=400)

# %%
type(bookings)
# Out:
# pandas.io.parsers.TextFileReader

# %%
bookings = pd.read_csv('bookings.csv', sep='^', usecols =['arr_port', 'pax', 'year'], chunksize=400)
for i, chunk in enumerate(bookings):
    print (chunk.head())
    if i == 3:
        break
# Out:
#    arr_port  pax  year
# 0  LHR        -1  2013
# 1  CLT         1  2013
# 2  CLT         1  2013
# 3  SVO         1  2013
# 4  SVO         1  2013
#      arr_port  pax  year
# 400  DCA        21  2013
# 401  ORD         1  2013
# 402  ORD         1  2013
# 403  ORD        -1  2013
# 404  ATL         1  2013
#      arr_port  pax  year
# 800  ORD         1  2013
# 801  ATQ         1  2013
# 802  ATQ         1  2013
# 803  ATQ        -1  2013
# 804  YVR         1  2013
#       arr_port  pax  year
# 1200  LHR         1  2013
# 1201  LHR        -1  2013
# 1202  IST         1  2013
# 1203  UIO         1  2013
# 1204  FLL         1  2013

# %%
chunk_bookings = pd.read_csv('bookings.csv', sep='^', usecols =['arr_port', 'pax', 'year'], chunksize=400)
sum_chunks = pd.DataFrame()


for i, bookings in enumerate (chunk_bookings):
    print ("Chunk: %d, size of chunk %d"%(i+1, len(bookings)))
    bookings = bookings[bookings['year'] == 2013]
    bookings.drop ('year', axis =1, inplace=True)
    arrival_airports = bookings.groupby ('arr_port')
    chunk_result = arrival_airports.sum()
    sum_chunks = sum_chunks.append (chunk_result)
sum_chunks.head()
# Out:
# Chunk: 1, size of chunk 400
# Chunk: 2, size of chunk 400
# Chunk: 3, size of chunk 400
# Chunk: 4, size of chunk 400
# Chunk: 5, size of chunk 400
# Chunk: 6, size of chunk 400
# Chunk: 7, size of chunk 400
# Chunk: 8, size of chunk 400
# Chunk: 9, size of chunk 400
# Chunk: 10, size of chunk 400
# Chunk: 11, size of chunk 400
# Chunk: 12, size of chunk 400
# Chunk: 13, size of chunk 400
# Chunk: 14, size of chunk 400
# Chunk: 15, size of chunk 400
# Chunk: 16, size of chunk 400
# Chunk: 17, size of chunk 400
# Chunk: 18, size of chunk 400
# Chunk: 19, size of chunk 400
# Chunk: 20, size of chunk 400
# Chunk: 21, size of chunk 400
# Chunk: 22, size of chunk 400
# Chunk: 23, size of chunk 400
# Chunk: 24, size of chunk 400
# Chunk: 25, size of chunk 400
# Chunk: 26, size of chunk 400
# Chunk: 27, size of chunk 400
# Chunk: 28, size of chunk 400
# Chunk: 29, size of chunk 400
# Chunk: 30, size of chunk 400
# Chunk: 31, size of chunk 400
# Chunk: 32, size of chunk 400
# Chunk: 33, size of chunk 400
# Chunk: 34, size of chunk 400
# Chunk: 35, size of chunk 400
# Chunk: 36, size of chunk 400
# Chunk: 37, size of chunk 400
# Chunk: 38, size of chunk 400
# Chunk: 39, size of chunk 400
# Chunk: 40, size of chunk 400
# Chunk: 41, size of chunk 400
# Chunk: 42, size of chunk 400
# Chunk: 43, size of chunk 400
# Chunk: 44, size of chunk 400
# Chunk: 45, size of chunk 400
# Chunk: 46, size of chunk 400
# Chunk: 47, size of chunk 400
# Chunk: 48, size of chunk 400
# Chunk: 49, size of chunk 400
# Chunk: 50, size of chunk 400
# Chunk: 51, size of chunk 400
# Chunk: 52, size of chunk 400
# Chunk: 53, size of chunk 400
# Chunk: 54, size of chunk 400
# Chunk: 55, size of chunk 400
# Chunk: 56, size of chunk 400
# Chunk: 57, size of chunk 400
# Chunk: 58, size of chunk 400
# Chunk: 59, size of chunk 400
# Chunk: 60, size of chunk 400
# Chunk: 61, size of chunk 400
# Chunk: 62, size of chunk 400
# Chunk: 63, size of chunk 400
# Chunk: 64, size of chunk 400
# Chunk: 65, size of chunk 400
# Chunk: 66, size of chunk 400
# Chunk: 67, size of chunk 400
# Chunk: 68, size of chunk 400
# Chunk: 69, size of chunk 400
# Chunk: 70, size of chunk 400
# Chunk: 71, size of chunk 400
# Chunk: 72, size of chunk 400
# Chunk: 73, size of chunk 400
# Chunk: 74, size of chunk 400
# Chunk: 75, size of chunk 400
# Chunk: 76, size of chunk 400
# Chunk: 77, size of chunk 400
# Chunk: 78, size of chunk 400
# Chunk: 79, size of chunk 400
# Chunk: 80, size of chunk 400
# Chunk: 81, size of chunk 400
# Chunk: 82, size of chunk 400
# Chunk: 83, size of chunk 400
# Chunk: 84, size of chunk 400
# Chunk: 85, size of chunk 400
# Chunk: 86, size of chunk 400
# Chunk: 87, size of chunk 400
# Chunk: 88, size of chunk 400
# Chunk: 89, size of chunk 400
# Chunk: 90, size of chunk 400
# Chunk: 91, size of chunk 400
# Chunk: 92, size of chunk 400
# Chunk: 93, size of chunk 400
# Chunk: 94, size of chunk 400
# Chunk: 95, size of chunk 400
# Chunk: 96, size of chunk 400
# Chunk: 97, size of chunk 400
# Chunk: 98, size of chunk 400
# Chunk: 99, size of chunk 400
# Chunk: 100, size of chunk 400
# Chunk: 101, size of chunk 400
# Chunk: 102, size of chunk 400
# Chunk: 103, size of chunk 400
# Chunk: 104, size of chunk 400
# Chunk: 105, size of chunk 400
# Chunk: 106, size of chunk 400
# Chunk: 107, size of chunk 400
# Chunk: 108, size of chunk 400
# Chunk: 109, size of chunk 400
# Chunk: 110, size of chunk 400
# Chunk: 111, size of chunk 400
# Chunk: 112, size of chunk 400
# Chunk: 113, size of chunk 400
# Chunk: 114, size of chunk 400
# Chunk: 115, size of chunk 400
# Chunk: 116, size of chunk 400
# Chunk: 117, size of chunk 400
# Chunk: 118, size of chunk 400
# Chunk: 119, size of chunk 400
# Chunk: 120, size of chunk 400
# Chunk: 121, size of chunk 400
# Chunk: 122, size of chunk 400
# Chunk: 123, size of chunk 400
# Chunk: 124, size of chunk 400
# Chunk: 125, size of chunk 400
# Chunk: 126, size of chunk 400
# Chunk: 127, size of chunk 400
# Chunk: 128, size of chunk 400
# Chunk: 129, size of chunk 400
# Chunk: 130, size of chunk 400
# Chunk: 131, size of chunk 400
# Chunk: 132, size of chunk 400
# Chunk: 133, size of chunk 400
# Chunk: 134, size of chunk 400
# Chunk: 135, size of chunk 400
# Chunk: 136, size of chunk 400
# Chunk: 137, size of chunk 400
# Chunk: 138, size of chunk 400
# Chunk: 139, size of chunk 400
# Chunk: 140, size of chunk 400
# Chunk: 141, size of chunk 400
# Chunk: 142, size of chunk 400
# Chunk: 143, size of chunk 400
# Chunk: 144, size of chunk 400
# Chunk: 145, size of chunk 400
# Chunk: 146, size of chunk 400
# Chunk: 147, size of chunk 400
# Chunk: 148, size of chunk 400
# Chunk: 149, size of chunk 400
# Chunk: 150, size of chunk 400
# Chunk: 151, size of chunk 400
# Chunk: 152, size of chunk 400
# Chunk: 153, size of chunk 400
# Chunk: 154, size of chunk 400
# Chunk: 155, size of chunk 400
# Chunk: 156, size of chunk 400
# Chunk: 157, size of chunk 400
# Chunk: 158, size of chunk 400
# Chunk: 159, size of chunk 400
# Chunk: 160, size of chunk 400
# Chunk: 161, size of chunk 400
# Chunk: 162, size of chunk 400
# Chunk: 163, size of chunk 400
# Chunk: 164, size of chunk 400
# Chunk: 165, size of chunk 400
# Chunk: 166, size of chunk 400
# Chunk: 167, size of chunk 400
# Chunk: 168, size of chunk 400
# Chunk: 169, size of chunk 400
# Chunk: 170, size of chunk 400
# Chunk: 171, size of chunk 400
# Chunk: 172, size of chunk 400
# Chunk: 173, size of chunk 400
# Chunk: 174, size of chunk 400
# Chunk: 175, size of chunk 400
# Chunk: 176, size of chunk 400
# Chunk: 177, size of chunk 400
# Chunk: 178, size of chunk 400
# Chunk: 179, size of chunk 400
# Chunk: 180, size of chunk 400
# Chunk: 181, size of chunk 400
# Chunk: 182, size of chunk 400
# Chunk: 183, size of chunk 400
# Chunk: 184, size of chunk 400
# Chunk: 185, size of chunk 400
# Chunk: 186, size of chunk 400
# Chunk: 187, size of chunk 400
# Chunk: 188, size of chunk 400
# Chunk: 189, size of chunk 400
# Chunk: 190, size of chunk 400
# Chunk: 191, size of chunk 400
# Chunk: 192, size of chunk 400
# Chunk: 193, size of chunk 400
# Chunk: 194, size of chunk 400
# Chunk: 195, size of chunk 400
# Chunk: 196, size of chunk 400
# Chunk: 197, size of chunk 400
# Chunk: 198, size of chunk 400
# Chunk: 199, size of chunk 400
# Chunk: 200, size of chunk 400
# Chunk: 201, size of chunk 400
# Chunk: 202, size of chunk 400
# Chunk: 203, size of chunk 400
# Chunk: 204, size of chunk 400
# Chunk: 205, size of chunk 400
# Chunk: 206, size of chunk 400
# Chunk: 207, size of chunk 400
# Chunk: 208, size of chunk 400
# Chunk: 209, size of chunk 400
# Chunk: 210, size of chunk 400
# Chunk: 211, size of chunk 400
# Chunk: 212, size of chunk 400
# Chunk: 213, size of chunk 400
# Chunk: 214, size of chunk 400
# Chunk: 215, size of chunk 400
# Chunk: 216, size of chunk 400
# Chunk: 217, size of chunk 400
# Chunk: 218, size of chunk 400
# Chunk: 219, size of chunk 400
# Chunk: 220, size of chunk 400
# Chunk: 221, size of chunk 400
# Chunk: 222, size of chunk 400
# Chunk: 223, size of chunk 400
# Chunk: 224, size of chunk 400
# Chunk: 225, size of chunk 400
# Chunk: 226, size of chunk 400
# Chunk: 227, size of chunk 400
# Chunk: 228, size of chunk 400
# Chunk: 229, size of chunk 400
# Chunk: 230, size of chunk 400
# Chunk: 231, size of chunk 400
# Chunk: 232, size of chunk 400
# Chunk: 233, size of chunk 400
# Chunk: 234, size of chunk 400
# Chunk: 235, size of chunk 400
# Chunk: 236, size of chunk 400
# Chunk: 237, size of chunk 400
# Chunk: 238, size of chunk 400
# Chunk: 239, size of chunk 400
# Chunk: 240, size of chunk 400
# Chunk: 241, size of chunk 400
# Chunk: 242, size of chunk 400
# Chunk: 243, size of chunk 400
# Chunk: 244, size of chunk 400
# Chunk: 245, size of chunk 400
# Chunk: 246, size of chunk 400
# Chunk: 247, size of chunk 400
# Chunk: 248, size of chunk 400
# Chunk: 249, size of chunk 400
# Chunk: 250, size of chunk 400
# Chunk: 251, size of chunk 400
# Chunk: 252, size of chunk 400
# Chunk: 253, size of chunk 400
# Chunk: 254, size of chunk 400
# Chunk: 255, size of chunk 400
# Chunk: 256, size of chunk 400
# Chunk: 257, size of chunk 400
# Chunk: 258, size of chunk 400
# Chunk: 259, size of chunk 400
# Chunk: 260, size of chunk 400
# Chunk: 261, size of chunk 400
# Chunk: 262, size of chunk 400
# Chunk: 263, size of chunk 400
# Chunk: 264, size of chunk 400
# Chunk: 265, size of chunk 400
# Chunk: 266, size of chunk 400
# Chunk: 267, size of chunk 400
# Chunk: 268, size of chunk 400
# Chunk: 269, size of chunk 400
# Chunk: 270, size of chunk 400
# Chunk: 271, size of chunk 400
# Chunk: 272, size of chunk 400
# Chunk: 273, size of chunk 400
# Chunk: 274, size of chunk 400
# Chunk: 275, size of chunk 400
# Chunk: 276, size of chunk 400
# Chunk: 277, size of chunk 400
# Chunk: 278, size of chunk 400
# Chunk: 279, size of chunk 400
# Chunk: 280, size of chunk 400
# Chunk: 281, size of chunk 400
# Chunk: 282, size of chunk 400
# Chunk: 283, size of chunk 400
# Chunk: 284, size of chunk 400
# Chunk: 285, size of chunk 400
# Chunk: 286, size of chunk 400
# Chunk: 287, size of chunk 400
# Chunk: 288, size of chunk 400
# Chunk: 289, size of chunk 400
# Chunk: 290, size of chunk 400
# Chunk: 291, size of chunk 400
# Chunk: 292, size of chunk 400
# Chunk: 293, size of chunk 400
# Chunk: 294, size of chunk 400
# Chunk: 295, size of chunk 400
# Chunk: 296, size of chunk 400
# Chunk: 297, size of chunk 400
# Chunk: 298, size of chunk 400
# Chunk: 299, size of chunk 400
# Chunk: 300, size of chunk 400
# Chunk: 301, size of chunk 400
# Chunk: 302, size of chunk 400
# Chunk: 303, size of chunk 400
# Chunk: 304, size of chunk 400
# Chunk: 305, size of chunk 400
# Chunk: 306, size of chunk 400
# Chunk: 307, size of chunk 400
# Chunk: 308, size of chunk 400
# Chunk: 309, size of chunk 400
# Chunk: 310, size of chunk 400
# Chunk: 311, size of chunk 400
# Chunk: 312, size of chunk 400
# Chunk: 313, size of chunk 400
# Chunk: 314, size of chunk 400
# Chunk: 315, size of chunk 400
# Chunk: 316, size of chunk 400
# Chunk: 317, size of chunk 400
# Chunk: 318, size of chunk 400
# Chunk: 319, size of chunk 400
# Chunk: 320, size of chunk 400
# Chunk: 321, size of chunk 400
# Chunk: 322, size of chunk 400
# Chunk: 323, size of chunk 400
# Chunk: 324, size of chunk 400
# Chunk: 325, size of chunk 400
# Chunk: 326, size of chunk 400
# Chunk: 327, size of chunk 400
# Chunk: 328, size of chunk 400
# Chunk: 329, size of chunk 400
# Chunk: 330, size of chunk 400
# Chunk: 331, size of chunk 400
# Chunk: 332, size of chunk 400
# Chunk: 333, size of chunk 400
# Chunk: 334, size of chunk 400
# Chunk: 335, size of chunk 400
# Chunk: 336, size of chunk 400
# Chunk: 337, size of chunk 400
# Chunk: 338, size of chunk 400
# Chunk: 339, size of chunk 400
# Chunk: 340, size of chunk 400
# Chunk: 341, size of chunk 400
# Chunk: 342, size of chunk 400
# Chunk: 343, size of chunk 400
# Chunk: 344, size of chunk 400
# Chunk: 345, size of chunk 400
# Chunk: 346, size of chunk 400
# Chunk: 347, size of chunk 400
# Chunk: 348, size of chunk 400
# Chunk: 349, size of chunk 400
# Chunk: 350, size of chunk 400
# Chunk: 351, size of chunk 400
# Chunk: 352, size of chunk 400
# Chunk: 353, size of chunk 400
# Chunk: 354, size of chunk 400
# Chunk: 355, size of chunk 400
# Chunk: 356, size of chunk 400
# Chunk: 357, size of chunk 400
# Chunk: 358, size of chunk 400
# Chunk: 359, size of chunk 400
# Chunk: 360, size of chunk 400
# Chunk: 361, size of chunk 400
# Chunk: 362, size of chunk 400
# Chunk: 363, size of chunk 400
# Chunk: 364, size of chunk 400
# Chunk: 365, size of chunk 400
# Chunk: 366, size of chunk 400
# Chunk: 367, size of chunk 400
# Chunk: 368, size of chunk 400
# Chunk: 369, size of chunk 400
# Chunk: 370, size of chunk 400
# Chunk: 371, size of chunk 400
# Chunk: 372, size of chunk 400
# Chunk: 373, size of chunk 400
# Chunk: 374, size of chunk 400
# Chunk: 375, size of chunk 400
# Chunk: 376, size of chunk 400
# Chunk: 377, size of chunk 400
# Chunk: 378, size of chunk 400
# Chunk: 379, size of chunk 400
# Chunk: 380, size of chunk 400
# Chunk: 381, size of chunk 400
# Chunk: 382, size of chunk 400
# Chunk: 383, size of chunk 400
# Chunk: 384, size of chunk 400
# Chunk: 385, size of chunk 400
# Chunk: 386, size of chunk 400
# Chunk: 387, size of chunk 400
# Chunk: 388, size of chunk 400
# Chunk: 389, size of chunk 400
# Chunk: 390, size of chunk 400
# Chunk: 391, size of chunk 400
# Chunk: 392, size of chunk 400
# Chunk: 393, size of chunk 400
# Chunk: 394, size of chunk 400
# Chunk: 395, size of chunk 400
# Chunk: 396, size of chunk 400
# Chunk: 397, size of chunk 400
# Chunk: 398, size of chunk 400
# Chunk: 399, size of chunk 400
# Chunk: 400, size of chunk 400
# Chunk: 401, size of chunk 400
# Chunk: 402, size of chunk 400
# Chunk: 403, size of chunk 400
# Chunk: 404, size of chunk 400
# Chunk: 405, size of chunk 400
# Chunk: 406, size of chunk 400
# Chunk: 407, size of chunk 400
# Chunk: 408, size of chunk 400
# Chunk: 409, size of chunk 400
# Chunk: 410, size of chunk 400
# Chunk: 411, size of chunk 400
# Chunk: 412, size of chunk 400
# Chunk: 413, size of chunk 400
# Chunk: 414, size of chunk 400
# Chunk: 415, size of chunk 400
# Chunk: 416, size of chunk 400
# Chunk: 417, size of chunk 400
# Chunk: 418, size of chunk 400
# Chunk: 419, size of chunk 400
# Chunk: 420, size of chunk 400
# Chunk: 421, size of chunk 400
# Chunk: 422, size of chunk 400
# Chunk: 423, size of chunk 400
# Chunk: 424, size of chunk 400
# Chunk: 425, size of chunk 400
# Chunk: 426, size of chunk 400
# Chunk: 427, size of chunk 400
# Chunk: 428, size of chunk 400
# Chunk: 429, size of chunk 400
# Chunk: 430, size of chunk 400
# Chunk: 431, size of chunk 400
# Chunk: 432, size of chunk 400
# Chunk: 433, size of chunk 400
# Chunk: 434, size of chunk 400
# Chunk: 435, size of chunk 400
# Chunk: 436, size of chunk 400
# Chunk: 437, size of chunk 400
# Chunk: 438, size of chunk 400
# Chunk: 439, size of chunk 400
# Chunk: 440, size of chunk 400
# Chunk: 441, size of chunk 400
# Chunk: 442, size of chunk 400
# Chunk: 443, size of chunk 400
# Chunk: 444, size of chunk 400
# Chunk: 445, size of chunk 400
# Chunk: 446, size of chunk 400
# Chunk: 447, size of chunk 400
# Chunk: 448, size of chunk 400
# Chunk: 449, size of chunk 400
# Chunk: 450, size of chunk 400
# Chunk: 451, size of chunk 400
# Chunk: 452, size of chunk 400
# Chunk: 453, size of chunk 400
# Chunk: 454, size of chunk 400
# Chunk: 455, size of chunk 400
# Chunk: 456, size of chunk 400
# Chunk: 457, size of chunk 400
# Chunk: 458, size of chunk 400
# Chunk: 459, size of chunk 400
# Chunk: 460, size of chunk 400
# Chunk: 461, size of chunk 400
# Chunk: 462, size of chunk 400
# Chunk: 463, size of chunk 400
# Chunk: 464, size of chunk 400
# Chunk: 465, size of chunk 400
# Chunk: 466, size of chunk 400
# Chunk: 467, size of chunk 400
# Chunk: 468, size of chunk 400
# Chunk: 469, size of chunk 400
# Chunk: 470, size of chunk 400
# Chunk: 471, size of chunk 400
# Chunk: 472, size of chunk 400
# Chunk: 473, size of chunk 400
# Chunk: 474, size of chunk 400
# Chunk: 475, size of chunk 400
# Chunk: 476, size of chunk 400
# Chunk: 477, size of chunk 400
# Chunk: 478, size of chunk 400
# Chunk: 479, size of chunk 400
# Chunk: 480, size of chunk 400
# Chunk: 481, size of chunk 400
# Chunk: 482, size of chunk 400
# Chunk: 483, size of chunk 400
# Chunk: 484, size of chunk 400
# Chunk: 485, size of chunk 400
# Chunk: 486, size of chunk 400
# Chunk: 487, size of chunk 400
# Chunk: 488, size of chunk 400
# Chunk: 489, size of chunk 400
# Chunk: 490, size of chunk 400
# Chunk: 491, size of chunk 400
# Chunk: 492, size of chunk 400
# Chunk: 493, size of chunk 400
# Chunk: 494, size of chunk 400
# Chunk: 495, size of chunk 400
# Chunk: 496, size of chunk 400
# Chunk: 497, size of chunk 400
# Chunk: 498, size of chunk 400
# Chunk: 499, size of chunk 400
# Chunk: 500, size of chunk 400
# Chunk: 501, size of chunk 400
# Chunk: 502, size of chunk 400
# Chunk: 503, size of chunk 400
# Chunk: 504, size of chunk 400
# Chunk: 505, size of chunk 400
# Chunk: 506, size of chunk 400
# Chunk: 507, size of chunk 400
# Chunk: 508, size of chunk 400
# Chunk: 509, size of chunk 400
# Chunk: 510, size of chunk 400
# Chunk: 511, size of chunk 400
# Chunk: 512, size of chunk 400
# Chunk: 513, size of chunk 400
# Chunk: 514, size of chunk 400
# Chunk: 515, size of chunk 400
# Chunk: 516, size of chunk 400
# Chunk: 517, size of chunk 400
# Chunk: 518, size of chunk 400
# Chunk: 519, size of chunk 400
# Chunk: 520, size of chunk 400
# Chunk: 521, size of chunk 400
# Chunk: 522, size of chunk 400
# Chunk: 523, size of chunk 400
# Chunk: 524, size of chunk 400
# Chunk: 525, size of chunk 400
# Chunk: 526, size of chunk 400
# Chunk: 527, size of chunk 400
# Chunk: 528, size of chunk 400
# Chunk: 529, size of chunk 400
# Chunk: 530, size of chunk 400
# Chunk: 531, size of chunk 400
# Chunk: 532, size of chunk 400
# Chunk: 533, size of chunk 400
# Chunk: 534, size of chunk 400
# Chunk: 535, size of chunk 400
# Chunk: 536, size of chunk 400
# Chunk: 537, size of chunk 400
# Chunk: 538, size of chunk 400
# Chunk: 539, size of chunk 400
# Chunk: 540, size of chunk 400
# Chunk: 541, size of chunk 400
# Chunk: 542, size of chunk 400
# Chunk: 543, size of chunk 400
# Chunk: 544, size of chunk 400
# Chunk: 545, size of chunk 400
# Chunk: 546, size of chunk 400
# Chunk: 547, size of chunk 400
# Chunk: 548, size of chunk 400
# Chunk: 549, size of chunk 400
# Chunk: 550, size of chunk 400
# Chunk: 551, size of chunk 400
# Chunk: 552, size of chunk 400
# Chunk: 553, size of chunk 400
# Chunk: 554, size of chunk 400
# Chunk: 555, size of chunk 400
# Chunk: 556, size of chunk 400
# Chunk: 557, size of chunk 400
# Chunk: 558, size of chunk 400
# Chunk: 559, size of chunk 400
# Chunk: 560, size of chunk 400
# Chunk: 561, size of chunk 400
# Chunk: 562, size of chunk 400
# Chunk: 563, size of chunk 400
# Chunk: 564, size of chunk 400
# Chunk: 565, size of chunk 400
# Chunk: 566, size of chunk 400
# Chunk: 567, size of chunk 400
# Chunk: 568, size of chunk 400
# Chunk: 569, size of chunk 400
# Chunk: 570, size of chunk 400
# Chunk: 571, size of chunk 400
# Chunk: 572, size of chunk 400
# Chunk: 573, size of chunk 400
# Chunk: 574, size of chunk 400
# Chunk: 575, size of chunk 400
# Chunk: 576, size of chunk 400
# Chunk: 577, size of chunk 400
# Chunk: 578, size of chunk 400
# Chunk: 579, size of chunk 400
# Chunk: 580, size of chunk 400
# Chunk: 581, size of chunk 400
# Chunk: 582, size of chunk 400
# Chunk: 583, size of chunk 400
# Chunk: 584, size of chunk 400
# Chunk: 585, size of chunk 400
# Chunk: 586, size of chunk 400
# Chunk: 587, size of chunk 400
# Chunk: 588, size of chunk 400
# Chunk: 589, size of chunk 400
# Chunk: 590, size of chunk 400
# Chunk: 591, size of chunk 400
# Chunk: 592, size of chunk 400
# Chunk: 593, size of chunk 400
# Chunk: 594, size of chunk 400
# Chunk: 595, size of chunk 400
# Chunk: 596, size of chunk 400
# Chunk: 597, size of chunk 400
# Chunk: 598, size of chunk 400
# Chunk: 599, size of chunk 400
# Chunk: 600, size of chunk 400
# Chunk: 601, size of chunk 400
# Chunk: 602, size of chunk 400
# Chunk: 603, size of chunk 400
# Chunk: 604, size of chunk 400
# Chunk: 605, size of chunk 400
# Chunk: 606, size of chunk 400
# Chunk: 607, size of chunk 400
# Chunk: 608, size of chunk 400
# Chunk: 609, size of chunk 400
# Chunk: 610, size of chunk 400
# Chunk: 611, size of chunk 400
# Chunk: 612, size of chunk 400
# Chunk: 613, size of chunk 400
# Chunk: 614, size of chunk 400
# Chunk: 615, size of chunk 400
# Chunk: 616, size of chunk 400
# Chunk: 617, size of chunk 400
# Chunk: 618, size of chunk 400
# Chunk: 619, size of chunk 400
# Chunk: 620, size of chunk 400
# Chunk: 621, size of chunk 400
# Chunk: 622, size of chunk 400
# Chunk: 623, size of chunk 400
# Chunk: 624, size of chunk 400
# Chunk: 625, size of chunk 400
# Chunk: 626, size of chunk 400
# Chunk: 627, size of chunk 400
# Chunk: 628, size of chunk 400
# Chunk: 629, size of chunk 400
# Chunk: 630, size of chunk 400
# Chunk: 631, size of chunk 400
# Chunk: 632, size of chunk 400
# Chunk: 633, size of chunk 400
# Chunk: 634, size of chunk 400
# Chunk: 635, size of chunk 400
# Chunk: 636, size of chunk 400
# Chunk: 637, size of chunk 400
# Chunk: 638, size of chunk 400
# Chunk: 639, size of chunk 400
# Chunk: 640, size of chunk 400
# Chunk: 641, size of chunk 400
# Chunk: 642, size of chunk 400
# Chunk: 643, size of chunk 400
# Chunk: 644, size of chunk 400
# Chunk: 645, size of chunk 400
# Chunk: 646, size of chunk 400
# Chunk: 647, size of chunk 400
# Chunk: 648, size of chunk 400
# Chunk: 649, size of chunk 400
# Chunk: 650, size of chunk 400
# Chunk: 651, size of chunk 400
# Chunk: 652, size of chunk 400
# Chunk: 653, size of chunk 400
# Chunk: 654, size of chunk 400
# Chunk: 655, size of chunk 400
# Chunk: 656, size of chunk 400
# Chunk: 657, size of chunk 400
# Chunk: 658, size of chunk 400
# Chunk: 659, size of chunk 400
# Chunk: 660, size of chunk 400
# Chunk: 661, size of chunk 400
# Chunk: 662, size of chunk 400
# Chunk: 663, size of chunk 400
# Chunk: 664, size of chunk 400
# Chunk: 665, size of chunk 400
# Chunk: 666, size of chunk 400
# Chunk: 667, size of chunk 400
# Chunk: 668, size of chunk 400
# Chunk: 669, size of chunk 400
# Chunk: 670, size of chunk 400
# Chunk: 671, size of chunk 400
# Chunk: 672, size of chunk 400
# Chunk: 673, size of chunk 400
# Chunk: 674, size of chunk 400
# Chunk: 675, size of chunk 400
# Chunk: 676, size of chunk 400
# Chunk: 677, size of chunk 400
# Chunk: 678, size of chunk 400
# Chunk: 679, size of chunk 400
# Chunk: 680, size of chunk 400
# Chunk: 681, size of chunk 400
# Chunk: 682, size of chunk 400
# Chunk: 683, size of chunk 400
# Chunk: 684, size of chunk 400
# Chunk: 685, size of chunk 400
# Chunk: 686, size of chunk 400
# Chunk: 687, size of chunk 400
# Chunk: 688, size of chunk 400
# Chunk: 689, size of chunk 400
# Chunk: 690, size of chunk 400
# Chunk: 691, size of chunk 400
# Chunk: 692, size of chunk 400
# Chunk: 693, size of chunk 400
# Chunk: 694, size of chunk 400
# Chunk: 695, size of chunk 400
# Chunk: 696, size of chunk 400
# Chunk: 697, size of chunk 400
# Chunk: 698, size of chunk 400
# Chunk: 699, size of chunk 400
# Chunk: 700, size of chunk 400
# Chunk: 701, size of chunk 400
# Chunk: 702, size of chunk 400
# Chunk: 703, size of chunk 400
# Chunk: 704, size of chunk 400
# Chunk: 705, size of chunk 400
# Chunk: 706, size of chunk 400
# Chunk: 707, size of chunk 400
# Chunk: 708, size of chunk 400
# Chunk: 709, size of chunk 400
# Chunk: 710, size of chunk 400
# Chunk: 711, size of chunk 400
# Chunk: 712, size of chunk 400
# Chunk: 713, size of chunk 400
# Chunk: 714, size of chunk 400
# Chunk: 715, size of chunk 400
# Chunk: 716, size of chunk 400
# Chunk: 717, size of chunk 400
# Chunk: 718, size of chunk 400
# Chunk: 719, size of chunk 400
# Chunk: 720, size of chunk 400
# Chunk: 721, size of chunk 400
# Chunk: 722, size of chunk 400
# Chunk: 723, size of chunk 400
# Chunk: 724, size of chunk 400
# Chunk: 725, size of chunk 400
# Chunk: 726, size of chunk 400
# Chunk: 727, size of chunk 400
# Chunk: 728, size of chunk 400
# Chunk: 729, size of chunk 400
# Chunk: 730, size of chunk 400
# Chunk: 731, size of chunk 400
# Chunk: 732, size of chunk 400
# Chunk: 733, size of chunk 400
# Chunk: 734, size of chunk 400
# Chunk: 735, size of chunk 400
# Chunk: 736, size of chunk 400
# Chunk: 737, size of chunk 400
# Chunk: 738, size of chunk 400
# Chunk: 739, size of chunk 400
# Chunk: 740, size of chunk 400
# Chunk: 741, size of chunk 400
# Chunk: 742, size of chunk 400
# Chunk: 743, size of chunk 400
# Chunk: 744, size of chunk 400
# Chunk: 745, size of chunk 400
# Chunk: 746, size of chunk 400
# Chunk: 747, size of chunk 400
# Chunk: 748, size of chunk 400
# Chunk: 749, size of chunk 400
# Chunk: 750, size of chunk 400
# Chunk: 751, size of chunk 400
# Chunk: 752, size of chunk 400
# Chunk: 753, size of chunk 400
# Chunk: 754, size of chunk 400
# Chunk: 755, size of chunk 400
# Chunk: 756, size of chunk 400
# Chunk: 757, size of chunk 400
# Chunk: 758, size of chunk 400
# Chunk: 759, size of chunk 400
# Chunk: 760, size of chunk 400
# Chunk: 761, size of chunk 400
# Chunk: 762, size of chunk 400
# Chunk: 763, size of chunk 400
# Chunk: 764, size of chunk 400
# Chunk: 765, size of chunk 400
# Chunk: 766, size of chunk 400
# Chunk: 767, size of chunk 400
# Chunk: 768, size of chunk 400
# Chunk: 769, size of chunk 400
# Chunk: 770, size of chunk 400
# Chunk: 771, size of chunk 400
# Chunk: 772, size of chunk 400
# Chunk: 773, size of chunk 400
# Chunk: 774, size of chunk 400
# Chunk: 775, size of chunk 400
# Chunk: 776, size of chunk 400
# Chunk: 777, size of chunk 400
# Chunk: 778, size of chunk 400
# Chunk: 779, size of chunk 400
# Chunk: 780, size of chunk 400
# Chunk: 781, size of chunk 400
# Chunk: 782, size of chunk 400
# Chunk: 783, size of chunk 400
# Chunk: 784, size of chunk 400
# Chunk: 785, size of chunk 400
# Chunk: 786, size of chunk 400
# Chunk: 787, size of chunk 400
# Chunk: 788, size of chunk 400
# Chunk: 789, size of chunk 400
# Chunk: 790, size of chunk 400
# Chunk: 791, size of chunk 400
# Chunk: 792, size of chunk 400
# Chunk: 793, size of chunk 400
# Chunk: 794, size of chunk 400
# Chunk: 795, size of chunk 400
# Chunk: 796, size of chunk 400
# Chunk: 797, size of chunk 400
# Chunk: 798, size of chunk 400
# Chunk: 799, size of chunk 400
# Chunk: 800, size of chunk 400
# Chunk: 801, size of chunk 400
# Chunk: 802, size of chunk 400
# Chunk: 803, size of chunk 400
# Chunk: 804, size of chunk 400
# Chunk: 805, size of chunk 400
# Chunk: 806, size of chunk 400
# Chunk: 807, size of chunk 400
# Chunk: 808, size of chunk 400
# Chunk: 809, size of chunk 400
# Chunk: 810, size of chunk 400
# Chunk: 811, size of chunk 400
# Chunk: 812, size of chunk 400
# Chunk: 813, size of chunk 400
# Chunk: 814, size of chunk 400
# Chunk: 815, size of chunk 400
# Chunk: 816, size of chunk 400
# Chunk: 817, size of chunk 400
# Chunk: 818, size of chunk 400
# Chunk: 819, size of chunk 400
# Chunk: 820, size of chunk 400
# Chunk: 821, size of chunk 400
# Chunk: 822, size of chunk 400
# Chunk: 823, size of chunk 400
# Chunk: 824, size of chunk 400
# Chunk: 825, size of chunk 400
# Chunk: 826, size of chunk 400
# Chunk: 827, size of chunk 400
# Chunk: 828, size of chunk 400
# Chunk: 829, size of chunk 400
# Chunk: 830, size of chunk 400
# Chunk: 831, size of chunk 400
# Chunk: 832, size of chunk 400
# Chunk: 833, size of chunk 400
# Chunk: 834, size of chunk 400
# Chunk: 835, size of chunk 400
# Chunk: 836, size of chunk 400
# Chunk: 837, size of chunk 400
# Chunk: 838, size of chunk 400
# Chunk: 839, size of chunk 400
# Chunk: 840, size of chunk 400
# Chunk: 841, size of chunk 400
# Chunk: 842, size of chunk 400
# Chunk: 843, size of chunk 400
# Chunk: 844, size of chunk 400
# Chunk: 845, size of chunk 400
# Chunk: 846, size of chunk 400
# Chunk: 847, size of chunk 400
# Chunk: 848, size of chunk 400
# Chunk: 849, size of chunk 400
# Chunk: 850, size of chunk 400
# Chunk: 851, size of chunk 400
# Chunk: 852, size of chunk 400
# Chunk: 853, size of chunk 400
# Chunk: 854, size of chunk 400
# Chunk: 855, size of chunk 400
# Chunk: 856, size of chunk 400
# Chunk: 857, size of chunk 400
# Chunk: 858, size of chunk 400
# Chunk: 859, size of chunk 400
# Chunk: 860, size of chunk 400
# Chunk: 861, size of chunk 400
# Chunk: 862, size of chunk 400
# Chunk: 863, size of chunk 400
# Chunk: 864, size of chunk 400
# Chunk: 865, size of chunk 400
# Chunk: 866, size of chunk 400
# Chunk: 867, size of chunk 400
# Chunk: 868, size of chunk 400
# Chunk: 869, size of chunk 400
# Chunk: 870, size of chunk 400
# Chunk: 871, size of chunk 400
# Chunk: 872, size of chunk 400
# Chunk: 873, size of chunk 400
# Chunk: 874, size of chunk 400
# Chunk: 875, size of chunk 400
# Chunk: 876, size of chunk 400
# Chunk: 877, size of chunk 400
# Chunk: 878, size of chunk 400
# Chunk: 879, size of chunk 400
# Chunk: 880, size of chunk 400
# Chunk: 881, size of chunk 400
# Chunk: 882, size of chunk 400
# Chunk: 883, size of chunk 400
# Chunk: 884, size of chunk 400
# Chunk: 885, size of chunk 400
# Chunk: 886, size of chunk 400
# Chunk: 887, size of chunk 400
# Chunk: 888, size of chunk 400
# Chunk: 889, size of chunk 400
# Chunk: 890, size of chunk 400
# Chunk: 891, size of chunk 400
# Chunk: 892, size of chunk 400
# Chunk: 893, size of chunk 400
# Chunk: 894, size of chunk 400
# Chunk: 895, size of chunk 400
# Chunk: 896, size of chunk 400
# Chunk: 897, size of chunk 400
# Chunk: 898, size of chunk 400
# Chunk: 899, size of chunk 400
# Chunk: 900, size of chunk 400
# Chunk: 901, size of chunk 400
# Chunk: 902, size of chunk 400
# Chunk: 903, size of chunk 400
# Chunk: 904, size of chunk 400
# Chunk: 905, size of chunk 400
# Chunk: 906, size of chunk 400
# Chunk: 907, size of chunk 400
# Chunk: 908, size of chunk 400
# Chunk: 909, size of chunk 400
# Chunk: 910, size of chunk 400
# Chunk: 911, size of chunk 400
# Chunk: 912, size of chunk 400
# Chunk: 913, size of chunk 400
# Chunk: 914, size of chunk 400
# Chunk: 915, size of chunk 400
# Chunk: 916, size of chunk 400
# Chunk: 917, size of chunk 400
# Chunk: 918, size of chunk 400
# Chunk: 919, size of chunk 400
# Chunk: 920, size of chunk 400
# Chunk: 921, size of chunk 400
# Chunk: 922, size of chunk 400
# Chunk: 923, size of chunk 400
# Chunk: 924, size of chunk 400
# Chunk: 925, size of chunk 400
# Chunk: 926, size of chunk 400
# Chunk: 927, size of chunk 400
# Chunk: 928, size of chunk 400
# Chunk: 929, size of chunk 400
# Chunk: 930, size of chunk 400
# Chunk: 931, size of chunk 400
# Chunk: 932, size of chunk 400
# Chunk: 933, size of chunk 400
# Chunk: 934, size of chunk 400
# Chunk: 935, size of chunk 400
# Chunk: 936, size of chunk 400
# Chunk: 937, size of chunk 400
# Chunk: 938, size of chunk 400
# Chunk: 939, size of chunk 400
# Chunk: 940, size of chunk 400
# Chunk: 941, size of chunk 400
# Chunk: 942, size of chunk 400
# Chunk: 943, size of chunk 400
# Chunk: 944, size of chunk 400
# Chunk: 945, size of chunk 400
# Chunk: 946, size of chunk 400
# Chunk: 947, size of chunk 400
# Chunk: 948, size of chunk 400
# Chunk: 949, size of chunk 400
# Chunk: 950, size of chunk 400
# Chunk: 951, size of chunk 400
# Chunk: 952, size of chunk 400
# Chunk: 953, size of chunk 400
# Chunk: 954, size of chunk 400
# Chunk: 955, size of chunk 400
# Chunk: 956, size of chunk 400
# Chunk: 957, size of chunk 400
# Chunk: 958, size of chunk 400
# Chunk: 959, size of chunk 400
# Chunk: 960, size of chunk 400
# Chunk: 961, size of chunk 400
# Chunk: 962, size of chunk 400
# Chunk: 963, size of chunk 400
# Chunk: 964, size of chunk 400
# Chunk: 965, size of chunk 400
# Chunk: 966, size of chunk 400
# Chunk: 967, size of chunk 400
# Chunk: 968, size of chunk 400
# Chunk: 969, size of chunk 400
# Chunk: 970, size of chunk 400
# Chunk: 971, size of chunk 400
# Chunk: 972, size of chunk 400
# Chunk: 973, size of chunk 400
# Chunk: 974, size of chunk 400
# Chunk: 975, size of chunk 400
# Chunk: 976, size of chunk 400
# Chunk: 977, size of chunk 400
# Chunk: 978, size of chunk 400
# Chunk: 979, size of chunk 400
# Chunk: 980, size of chunk 400
# Chunk: 981, size of chunk 400
# Chunk: 982, size of chunk 400
# Chunk: 983, size of chunk 400
# Chunk: 984, size of chunk 400
# Chunk: 985, size of chunk 400
# Chunk: 986, size of chunk 400
# Chunk: 987, size of chunk 400
# Chunk: 988, size of chunk 400
# Chunk: 989, size of chunk 400
# Chunk: 990, size of chunk 400
# Chunk: 991, size of chunk 400
# Chunk: 992, size of chunk 400
# Chunk: 993, size of chunk 400
# Chunk: 994, size of chunk 400
# Chunk: 995, size of chunk 400
# Chunk: 996, size of chunk 400
# Chunk: 997, size of chunk 400
# Chunk: 998, size of chunk 400
# Chunk: 999, size of chunk 400
# Chunk: 1000, size of chunk 400
# Chunk: 1001, size of chunk 400
# Chunk: 1002, size of chunk 400
# Chunk: 1003, size of chunk 400
# Chunk: 1004, size of chunk 400
# Chunk: 1005, size of chunk 400
# Chunk: 1006, size of chunk 400
# Chunk: 1007, size of chunk 400
# Chunk: 1008, size of chunk 400
# Chunk: 1009, size of chunk 400
# Chunk: 1010, size of chunk 400
# Chunk: 1011, size of chunk 400
# Chunk: 1012, size of chunk 400
# Chunk: 1013, size of chunk 400
# Chunk: 1014, size of chunk 400
# Chunk: 1015, size of chunk 400
# Chunk: 1016, size of chunk 400
# Chunk: 1017, size of chunk 400
# Chunk: 1018, size of chunk 400
# Chunk: 1019, size of chunk 400
# Chunk: 1020, size of chunk 400
# Chunk: 1021, size of chunk 400
# Chunk: 1022, size of chunk 400
# Chunk: 1023, size of chunk 400
# Chunk: 1024, size of chunk 400
# Chunk: 1025, size of chunk 400
# Chunk: 1026, size of chunk 400
# Chunk: 1027, size of chunk 400
# Chunk: 1028, size of chunk 400
# Chunk: 1029, size of chunk 400
# Chunk: 1030, size of chunk 400
# Chunk: 1031, size of chunk 400
# Chunk: 1032, size of chunk 400
# Chunk: 1033, size of chunk 400
# Chunk: 1034, size of chunk 400
# Chunk: 1035, size of chunk 400
# Chunk: 1036, size of chunk 400
# Chunk: 1037, size of chunk 400
# Chunk: 1038, size of chunk 400
# Chunk: 1039, size of chunk 400
# Chunk: 1040, size of chunk 400
# Chunk: 1041, size of chunk 400
# Chunk: 1042, size of chunk 400
# Chunk: 1043, size of chunk 400
# Chunk: 1044, size of chunk 400
# Chunk: 1045, size of chunk 400
# Chunk: 1046, size of chunk 400
# Chunk: 1047, size of chunk 400
# Chunk: 1048, size of chunk 400
# Chunk: 1049, size of chunk 400
# Chunk: 1050, size of chunk 400
# Chunk: 1051, size of chunk 400
# Chunk: 1052, size of chunk 400
# Chunk: 1053, size of chunk 400
# Chunk: 1054, size of chunk 400
# Chunk: 1055, size of chunk 400
# Chunk: 1056, size of chunk 400
# Chunk: 1057, size of chunk 400
# Chunk: 1058, size of chunk 400
# Chunk: 1059, size of chunk 400
# Chunk: 1060, size of chunk 400
# Chunk: 1061, size of chunk 400
# Chunk: 1062, size of chunk 400
# Chunk: 1063, size of chunk 400
# Chunk: 1064, size of chunk 400
# Chunk: 1065, size of chunk 400
# Chunk: 1066, size of chunk 400
# Chunk: 1067, size of chunk 400
# Chunk: 1068, size of chunk 400
# Chunk: 1069, size of chunk 400
# Chunk: 1070, size of chunk 400
# Chunk: 1071, size of chunk 400
# Chunk: 1072, size of chunk 400
# Chunk: 1073, size of chunk 400
# Chunk: 1074, size of chunk 400
# Chunk: 1075, size of chunk 400
# Chunk: 1076, size of chunk 400
# Chunk: 1077, size of chunk 400
# Chunk: 1078, size of chunk 400
# Chunk: 1079, size of chunk 400
# Chunk: 1080, size of chunk 400
# Chunk: 1081, size of chunk 400
# Chunk: 1082, size of chunk 400
# Chunk: 1083, size of chunk 400
# Chunk: 1084, size of chunk 400
# Chunk: 1085, size of chunk 400
# Chunk: 1086, size of chunk 400
# Chunk: 1087, size of chunk 400
# Chunk: 1088, size of chunk 400
# Chunk: 1089, size of chunk 400
# Chunk: 1090, size of chunk 400
# Chunk: 1091, size of chunk 400
# Chunk: 1092, size of chunk 400
# Chunk: 1093, size of chunk 400
# Chunk: 1094, size of chunk 400
# Chunk: 1095, size of chunk 400
# Chunk: 1096, size of chunk 400
# Chunk: 1097, size of chunk 400
# Chunk: 1098, size of chunk 400
# Chunk: 1099, size of chunk 400
# Chunk: 1100, size of chunk 400
# Chunk: 1101, size of chunk 400
# Chunk: 1102, size of chunk 400
# Chunk: 1103, size of chunk 400
# Chunk: 1104, size of chunk 400
# Chunk: 1105, size of chunk 400
# Chunk: 1106, size of chunk 400
# Chunk: 1107, size of chunk 400
# Chunk: 1108, size of chunk 400
# Chunk: 1109, size of chunk 400
# Chunk: 1110, size of chunk 400
# Chunk: 1111, size of chunk 400
# Chunk: 1112, size of chunk 400
# Chunk: 1113, size of chunk 400
# Chunk: 1114, size of chunk 400
# Chunk: 1115, size of chunk 400
# Chunk: 1116, size of chunk 400
# Chunk: 1117, size of chunk 400
# Chunk: 1118, size of chunk 400
# Chunk: 1119, size of chunk 400
# Chunk: 1120, size of chunk 400
# Chunk: 1121, size of chunk 400
# Chunk: 1122, size of chunk 400
# Chunk: 1123, size of chunk 400
# Chunk: 1124, size of chunk 400
# Chunk: 1125, size of chunk 400
# Chunk: 1126, size of chunk 400
# Chunk: 1127, size of chunk 400
# Chunk: 1128, size of chunk 400
# Chunk: 1129, size of chunk 400
# Chunk: 1130, size of chunk 400
# Chunk: 1131, size of chunk 400
# Chunk: 1132, size of chunk 400
# Chunk: 1133, size of chunk 400
# Chunk: 1134, size of chunk 400
# Chunk: 1135, size of chunk 400
# Chunk: 1136, size of chunk 400
# Chunk: 1137, size of chunk 400
# Chunk: 1138, size of chunk 400
# Chunk: 1139, size of chunk 400
# Chunk: 1140, size of chunk 400
# Chunk: 1141, size of chunk 400
# Chunk: 1142, size of chunk 400
# Chunk: 1143, size of chunk 400
# Chunk: 1144, size of chunk 400
# Chunk: 1145, size of chunk 400
# Chunk: 1146, size of chunk 400
# Chunk: 1147, size of chunk 400
# Chunk: 1148, size of chunk 400
# Chunk: 1149, size of chunk 400
# Chunk: 1150, size of chunk 400
# Chunk: 1151, size of chunk 400
# Chunk: 1152, size of chunk 400
# Chunk: 1153, size of chunk 400
# Chunk: 1154, size of chunk 400
# Chunk: 1155, size of chunk 400
# Chunk: 1156, size of chunk 400
# Chunk: 1157, size of chunk 400
# Chunk: 1158, size of chunk 400
# Chunk: 1159, size of chunk 400
# Chunk: 1160, size of chunk 400
# Chunk: 1161, size of chunk 400
# Chunk: 1162, size of chunk 400
# Chunk: 1163, size of chunk 400
# Chunk: 1164, size of chunk 400
# Chunk: 1165, size of chunk 400
# Chunk: 1166, size of chunk 400
# Chunk: 1167, size of chunk 400
# Chunk: 1168, size of chunk 400
# Chunk: 1169, size of chunk 400
# Chunk: 1170, size of chunk 400
# Chunk: 1171, size of chunk 400
# Chunk: 1172, size of chunk 400
# Chunk: 1173, size of chunk 400
# Chunk: 1174, size of chunk 400
# Chunk: 1175, size of chunk 400
# Chunk: 1176, size of chunk 400
# Chunk: 1177, size of chunk 400
# Chunk: 1178, size of chunk 400
# Chunk: 1179, size of chunk 400
# Chunk: 1180, size of chunk 400
# Chunk: 1181, size of chunk 400
# Chunk: 1182, size of chunk 400
# Chunk: 1183, size of chunk 400
# Chunk: 1184, size of chunk 400
# Chunk: 1185, size of chunk 400
# Chunk: 1186, size of chunk 400
# Chunk: 1187, size of chunk 400
# Chunk: 1188, size of chunk 400
# Chunk: 1189, size of chunk 400
# Chunk: 1190, size of chunk 400
# Chunk: 1191, size of chunk 400
# Chunk: 1192, size of chunk 400
# Chunk: 1193, size of chunk 400
# Chunk: 1194, size of chunk 400
# Chunk: 1195, size of chunk 400
# Chunk: 1196, size of chunk 400
# Chunk: 1197, size of chunk 400
# Chunk: 1198, size of chunk 400
# Chunk: 1199, size of chunk 400
# Chunk: 1200, size of chunk 400
# Chunk: 1201, size of chunk 400
# Chunk: 1202, size of chunk 400
# Chunk: 1203, size of chunk 400
# Chunk: 1204, size of chunk 400
# Chunk: 1205, size of chunk 400
# Chunk: 1206, size of chunk 400
# Chunk: 1207, size of chunk 400
# Chunk: 1208, size of chunk 400
# Chunk: 1209, size of chunk 400
# Chunk: 1210, size of chunk 400
# Chunk: 1211, size of chunk 400
# Chunk: 1212, size of chunk 400
# Chunk: 1213, size of chunk 400
# Chunk: 1214, size of chunk 400
# Chunk: 1215, size of chunk 400
# Chunk: 1216, size of chunk 400
# Chunk: 1217, size of chunk 400
# Chunk: 1218, size of chunk 400
# Chunk: 1219, size of chunk 400
# Chunk: 1220, size of chunk 400
# Chunk: 1221, size of chunk 400
# Chunk: 1222, size of chunk 400
# Chunk: 1223, size of chunk 400
# Chunk: 1224, size of chunk 400
# Chunk: 1225, size of chunk 400
# Chunk: 1226, size of chunk 400
# Chunk: 1227, size of chunk 400
# Chunk: 1228, size of chunk 400
# Chunk: 1229, size of chunk 400
# Chunk: 1230, size of chunk 400
# Chunk: 1231, size of chunk 400
# Chunk: 1232, size of chunk 400
# Chunk: 1233, size of chunk 400
# Chunk: 1234, size of chunk 400
# Chunk: 1235, size of chunk 400
# Chunk: 1236, size of chunk 400
# Chunk: 1237, size of chunk 400
# Chunk: 1238, size of chunk 400
# Chunk: 1239, size of chunk 400
# Chunk: 1240, size of chunk 400
# Chunk: 1241, size of chunk 400
# Chunk: 1242, size of chunk 400
# Chunk: 1243, size of chunk 400
# Chunk: 1244, size of chunk 400
# Chunk: 1245, size of chunk 400
# Chunk: 1246, size of chunk 400
# Chunk: 1247, size of chunk 400
# Chunk: 1248, size of chunk 400
# Chunk: 1249, size of chunk 400
# Chunk: 1250, size of chunk 400
# Chunk: 1251, size of chunk 400
# Chunk: 1252, size of chunk 400
# Chunk: 1253, size of chunk 400
# Chunk: 1254, size of chunk 400
# Chunk: 1255, size of chunk 400
# Chunk: 1256, size of chunk 400
# Chunk: 1257, size of chunk 400
# Chunk: 1258, size of chunk 400
# Chunk: 1259, size of chunk 400
# Chunk: 1260, size of chunk 400
# Chunk: 1261, size of chunk 400
# Chunk: 1262, size of chunk 400
# Chunk: 1263, size of chunk 400
# Chunk: 1264, size of chunk 400
# Chunk: 1265, size of chunk 400
# Chunk: 1266, size of chunk 400
# Chunk: 1267, size of chunk 400
# Chunk: 1268, size of chunk 400
# Chunk: 1269, size of chunk 400
# Chunk: 1270, size of chunk 400
# Chunk: 1271, size of chunk 400
# Chunk: 1272, size of chunk 400
# Chunk: 1273, size of chunk 400
# Chunk: 1274, size of chunk 400
# Chunk: 1275, size of chunk 400
# Chunk: 1276, size of chunk 400
# Chunk: 1277, size of chunk 400
# Chunk: 1278, size of chunk 400
# Chunk: 1279, size of chunk 400
# Chunk: 1280, size of chunk 400
# Chunk: 1281, size of chunk 400
# Chunk: 1282, size of chunk 400
# Chunk: 1283, size of chunk 400
# Chunk: 1284, size of chunk 400
# Chunk: 1285, size of chunk 400
# Chunk: 1286, size of chunk 400
# Chunk: 1287, size of chunk 400
# Chunk: 1288, size of chunk 400
# Chunk: 1289, size of chunk 400
# Chunk: 1290, size of chunk 400
# Chunk: 1291, size of chunk 400
# Chunk: 1292, size of chunk 400
# Chunk: 1293, size of chunk 400
# Chunk: 1294, size of chunk 400
# Chunk: 1295, size of chunk 400
# Chunk: 1296, size of chunk 400
# Chunk: 1297, size of chunk 400
# Chunk: 1298, size of chunk 400
# Chunk: 1299, size of chunk 400
# Chunk: 1300, size of chunk 400
# Chunk: 1301, size of chunk 400
# Chunk: 1302, size of chunk 400
# Chunk: 1303, size of chunk 400
# Chunk: 1304, size of chunk 400
# Chunk: 1305, size of chunk 400
# Chunk: 1306, size of chunk 400
# Chunk: 1307, size of chunk 400
# Chunk: 1308, size of chunk 400
# Chunk: 1309, size of chunk 400
# Chunk: 1310, size of chunk 400
# Chunk: 1311, size of chunk 400
# Chunk: 1312, size of chunk 400
# Chunk: 1313, size of chunk 400
# Chunk: 1314, size of chunk 400
# Chunk: 1315, size of chunk 400
# Chunk: 1316, size of chunk 400
# Chunk: 1317, size of chunk 400
# Chunk: 1318, size of chunk 400
# Chunk: 1319, size of chunk 400
# Chunk: 1320, size of chunk 400
# Chunk: 1321, size of chunk 400
# Chunk: 1322, size of chunk 400
# Chunk: 1323, size of chunk 400
# Chunk: 1324, size of chunk 400
# Chunk: 1325, size of chunk 400
# Chunk: 1326, size of chunk 400
# Chunk: 1327, size of chunk 400
# Chunk: 1328, size of chunk 400
# Chunk: 1329, size of chunk 400
# Chunk: 1330, size of chunk 400
# Chunk: 1331, size of chunk 400
# Chunk: 1332, size of chunk 400
# Chunk: 1333, size of chunk 400
# Chunk: 1334, size of chunk 400
# Chunk: 1335, size of chunk 400
# Chunk: 1336, size of chunk 400
# Chunk: 1337, size of chunk 400
# Chunk: 1338, size of chunk 400
# Chunk: 1339, size of chunk 400
# Chunk: 1340, size of chunk 400
# Chunk: 1341, size of chunk 400
# Chunk: 1342, size of chunk 400
# Chunk: 1343, size of chunk 400
# Chunk: 1344, size of chunk 400
# Chunk: 1345, size of chunk 400
# Chunk: 1346, size of chunk 400
# Chunk: 1347, size of chunk 400
# Chunk: 1348, size of chunk 400
# Chunk: 1349, size of chunk 400
# Chunk: 1350, size of chunk 400
# Chunk: 1351, size of chunk 400
# Chunk: 1352, size of chunk 400
# Chunk: 1353, size of chunk 400
# Chunk: 1354, size of chunk 400
# Chunk: 1355, size of chunk 400
# Chunk: 1356, size of chunk 400
# Chunk: 1357, size of chunk 400
# Chunk: 1358, size of chunk 400
# Chunk: 1359, size of chunk 400
# Chunk: 1360, size of chunk 400
# Chunk: 1361, size of chunk 400
# Chunk: 1362, size of chunk 400
# Chunk: 1363, size of chunk 400
# Chunk: 1364, size of chunk 400
# Chunk: 1365, size of chunk 400
# Chunk: 1366, size of chunk 400
# Chunk: 1367, size of chunk 400
# Chunk: 1368, size of chunk 400
# Chunk: 1369, size of chunk 400
# Chunk: 1370, size of chunk 400
# Chunk: 1371, size of chunk 400
# Chunk: 1372, size of chunk 400
# Chunk: 1373, size of chunk 400
# Chunk: 1374, size of chunk 400
# Chunk: 1375, size of chunk 400
# Chunk: 1376, size of chunk 400
# Chunk: 1377, size of chunk 400
# Chunk: 1378, size of chunk 400
# Chunk: 1379, size of chunk 400
# Chunk: 1380, size of chunk 400
# Chunk: 1381, size of chunk 400
# Chunk: 1382, size of chunk 400
# Chunk: 1383, size of chunk 400
# Chunk: 1384, size of chunk 400
# Chunk: 1385, size of chunk 400
# Chunk: 1386, size of chunk 400
# Chunk: 1387, size of chunk 400
# Chunk: 1388, size of chunk 400
# Chunk: 1389, size of chunk 400
# Chunk: 1390, size of chunk 400
# Chunk: 1391, size of chunk 400
# Chunk: 1392, size of chunk 400
# Chunk: 1393, size of chunk 400
# Chunk: 1394, size of chunk 400
# Chunk: 1395, size of chunk 400
# Chunk: 1396, size of chunk 400
# Chunk: 1397, size of chunk 400
# Chunk: 1398, size of chunk 400
# Chunk: 1399, size of chunk 400
# Chunk: 1400, size of chunk 400
# Chunk: 1401, size of chunk 400
# Chunk: 1402, size of chunk 400
# Chunk: 1403, size of chunk 400
# Chunk: 1404, size of chunk 400
# Chunk: 1405, size of chunk 400
# Chunk: 1406, size of chunk 400
# Chunk: 1407, size of chunk 400
# Chunk: 1408, size of chunk 400
# Chunk: 1409, size of chunk 400
# Chunk: 1410, size of chunk 400
# Chunk: 1411, size of chunk 400
# Chunk: 1412, size of chunk 400
# Chunk: 1413, size of chunk 400
# Chunk: 1414, size of chunk 400
# Chunk: 1415, size of chunk 400
# Chunk: 1416, size of chunk 400
# Chunk: 1417, size of chunk 400
# Chunk: 1418, size of chunk 400
# Chunk: 1419, size of chunk 400
# Chunk: 1420, size of chunk 400
# Chunk: 1421, size of chunk 400
# Chunk: 1422, size of chunk 400
# Chunk: 1423, size of chunk 400
# Chunk: 1424, size of chunk 400
# Chunk: 1425, size of chunk 400
# Chunk: 1426, size of chunk 400
# Chunk: 1427, size of chunk 400
# Chunk: 1428, size of chunk 400
# Chunk: 1429, size of chunk 400
# Chunk: 1430, size of chunk 400
# Chunk: 1431, size of chunk 400
# Chunk: 1432, size of chunk 400
# Chunk: 1433, size of chunk 400
# Chunk: 1434, size of chunk 400
# Chunk: 1435, size of chunk 400
# Chunk: 1436, size of chunk 400
# Chunk: 1437, size of chunk 400
# Chunk: 1438, size of chunk 400
# Chunk: 1439, size of chunk 400
# Chunk: 1440, size of chunk 400
# Chunk: 1441, size of chunk 400
# Chunk: 1442, size of chunk 400
# Chunk: 1443, size of chunk 400
# Chunk: 1444, size of chunk 400
# Chunk: 1445, size of chunk 400
# Chunk: 1446, size of chunk 400
# Chunk: 1447, size of chunk 400
# Chunk: 1448, size of chunk 400
# Chunk: 1449, size of chunk 400
# Chunk: 1450, size of chunk 400
# Chunk: 1451, size of chunk 400
# Chunk: 1452, size of chunk 400
# Chunk: 1453, size of chunk 400
# Chunk: 1454, size of chunk 400
# Chunk: 1455, size of chunk 400
# Chunk: 1456, size of chunk 400
# Chunk: 1457, size of chunk 400
# Chunk: 1458, size of chunk 400
# Chunk: 1459, size of chunk 400
# Chunk: 1460, size of chunk 400
# Chunk: 1461, size of chunk 400
# Chunk: 1462, size of chunk 400
# Chunk: 1463, size of chunk 400
# Chunk: 1464, size of chunk 400
# Chunk: 1465, size of chunk 400
# Chunk: 1466, size of chunk 400
# Chunk: 1467, size of chunk 400
# Chunk: 1468, size of chunk 400
# Chunk: 1469, size of chunk 400
# Chunk: 1470, size of chunk 400
# Chunk: 1471, size of chunk 400
# Chunk: 1472, size of chunk 400
# Chunk: 1473, size of chunk 400
# Chunk: 1474, size of chunk 400
# Chunk: 1475, size of chunk 400
# Chunk: 1476, size of chunk 400
# Chunk: 1477, size of chunk 400
# Chunk: 1478, size of chunk 400
# Chunk: 1479, size of chunk 400
# Chunk: 1480, size of chunk 400
# Chunk: 1481, size of chunk 400
# Chunk: 1482, size of chunk 400
# Chunk: 1483, size of chunk 400
# Chunk: 1484, size of chunk 400
# Chunk: 1485, size of chunk 400
# Chunk: 1486, size of chunk 400
# Chunk: 1487, size of chunk 400
# Chunk: 1488, size of chunk 400
# Chunk: 1489, size of chunk 400
# Chunk: 1490, size of chunk 400
# Chunk: 1491, size of chunk 400
# Chunk: 1492, size of chunk 400
# Chunk: 1493, size of chunk 400
# Chunk: 1494, size of chunk 400
# Chunk: 1495, size of chunk 400
# Chunk: 1496, size of chunk 400
# Chunk: 1497, size of chunk 400
# Chunk: 1498, size of chunk 400
# Chunk: 1499, size of chunk 400
# Chunk: 1500, size of chunk 400
# Chunk: 1501, size of chunk 400
# Chunk: 1502, size of chunk 400
# Chunk: 1503, size of chunk 400
# Chunk: 1504, size of chunk 400
# Chunk: 1505, size of chunk 400
# Chunk: 1506, size of chunk 400
# Chunk: 1507, size of chunk 400
# Chunk: 1508, size of chunk 400
# Chunk: 1509, size of chunk 400
# Chunk: 1510, size of chunk 400
# Chunk: 1511, size of chunk 400
# Chunk: 1512, size of chunk 400
# Chunk: 1513, size of chunk 400
# Chunk: 1514, size of chunk 400
# Chunk: 1515, size of chunk 400
# Chunk: 1516, size of chunk 400
# Chunk: 1517, size of chunk 400
# Chunk: 1518, size of chunk 400
# Chunk: 1519, size of chunk 400
# Chunk: 1520, size of chunk 400
# Chunk: 1521, size of chunk 400
# Chunk: 1522, size of chunk 400
# Chunk: 1523, size of chunk 400
# Chunk: 1524, size of chunk 400
# Chunk: 1525, size of chunk 400
# Chunk: 1526, size of chunk 400
# Chunk: 1527, size of chunk 400
# Chunk: 1528, size of chunk 400
# Chunk: 1529, size of chunk 400
# Chunk: 1530, size of chunk 400
# Chunk: 1531, size of chunk 400
# Chunk: 1532, size of chunk 400
# Chunk: 1533, size of chunk 400
# Chunk: 1534, size of chunk 400
# Chunk: 1535, size of chunk 400
# Chunk: 1536, size of chunk 400
# Chunk: 1537, size of chunk 400
# Chunk: 1538, size of chunk 400
# Chunk: 1539, size of chunk 400
# Chunk: 1540, size of chunk 400
# Chunk: 1541, size of chunk 400
# Chunk: 1542, size of chunk 400
# Chunk: 1543, size of chunk 400
# Chunk: 1544, size of chunk 400
# Chunk: 1545, size of chunk 400
# Chunk: 1546, size of chunk 400
# Chunk: 1547, size of chunk 400
# Chunk: 1548, size of chunk 400
# Chunk: 1549, size of chunk 400
# Chunk: 1550, size of chunk 400
# Chunk: 1551, size of chunk 400
# Chunk: 1552, size of chunk 400
# Chunk: 1553, size of chunk 400
# Chunk: 1554, size of chunk 400
# Chunk: 1555, size of chunk 400
# Chunk: 1556, size of chunk 400
# Chunk: 1557, size of chunk 400
# Chunk: 1558, size of chunk 400
# Chunk: 1559, size of chunk 400
# Chunk: 1560, size of chunk 400
# Chunk: 1561, size of chunk 400
# Chunk: 1562, size of chunk 400
# Chunk: 1563, size of chunk 400
# Chunk: 1564, size of chunk 400
# Chunk: 1565, size of chunk 400
# Chunk: 1566, size of chunk 400
# Chunk: 1567, size of chunk 400
# Chunk: 1568, size of chunk 400
# Chunk: 1569, size of chunk 400
# Chunk: 1570, size of chunk 400
# Chunk: 1571, size of chunk 400
# Chunk: 1572, size of chunk 400
# Chunk: 1573, size of chunk 400
# Chunk: 1574, size of chunk 400
# Chunk: 1575, size of chunk 400
# Chunk: 1576, size of chunk 400
# Chunk: 1577, size of chunk 400
# Chunk: 1578, size of chunk 400
# Chunk: 1579, size of chunk 400
# Chunk: 1580, size of chunk 400
# Chunk: 1581, size of chunk 400
# Chunk: 1582, size of chunk 400
# Chunk: 1583, size of chunk 400
# Chunk: 1584, size of chunk 400
# ...
# Chunk: 6966, size of chunk 400
# Chunk: 6967, size of chunk 400
# Chunk: 6968, size of chunk 400
# Chunk: 6969, size of chunk 400
# Chunk: 6970, size of chunk 400
# Chunk: 6971, size of chunk 400
# Chunk: 6972, size of chunk 400
# Chunk: 6973, size of chunk 400
# Chunk: 6974, size of chunk 400
# Chunk: 6975, size of chunk 400
# Chunk: 6976, size of chunk 400
# Chunk: 6977, size of chunk 400
# Chunk: 6978, size of chunk 400
# Chunk: 6979, size of chunk 400
# Chunk: 6980, size of chunk 400
# Chunk: 6981, size of chunk 400
# Chunk: 6982, size of chunk 400
# Chunk: 6983, size of chunk 400
# Chunk: 6984, size of chunk 400
# Chunk: 6985, size of chunk 400
# Chunk: 6986, size of chunk 400
# Chunk: 6987, size of chunk 400
# Chunk: 6988, size of chunk 400
# Chunk: 6989, size of chunk 400
# Chunk: 6990, size of chunk 400
# Chunk: 6991, size of chunk 400
# Chunk: 6992, size of chunk 400
# Chunk: 6993, size of chunk 400
# Chunk: 6994, size of chunk 400
# Chunk: 6995, size of chunk 400
# Chunk: 6996, size of chunk 400
# Chunk: 6997, size of chunk 400
# Chunk: 6998, size of chunk 400
# Chunk: 6999, size of chunk 400
# Chunk: 7000, size of chunk 400
# Chunk: 7001, size of chunk 400
# Chunk: 7002, size of chunk 400
# Chunk: 7003, size of chunk 400
# Chunk: 7004, size of chunk 400
# Chunk: 7005, size of chunk 400
# Chunk: 7006, size of chunk 400
# Chunk: 7007, size of chunk 400
# Chunk: 7008, size of chunk 400
# Chunk: 7009, size of chunk 400
# Chunk: 7010, size of chunk 400
# Chunk: 7011, size of chunk 400
# Chunk: 7012, size of chunk 400
# Chunk: 7013, size of chunk 400
# Chunk: 7014, size of chunk 400
# Chunk: 7015, size of chunk 400
# Chunk: 7016, size of chunk 400
# Chunk: 7017, size of chunk 400
# Chunk: 7018, size of chunk 400
# Chunk: 7019, size of chunk 400
# Chunk: 7020, size of chunk 400
# Chunk: 7021, size of chunk 400
# Chunk: 7022, size of chunk 400
# Chunk: 7023, size of chunk 400
# Chunk: 7024, size of chunk 400
# Chunk: 7025, size of chunk 400
# Chunk: 7026, size of chunk 400
# Chunk: 7027, size of chunk 400
# Chunk: 7028, size of chunk 400
# Chunk: 7029, size of chunk 400
# Chunk: 7030, size of chunk 400
# Chunk: 7031, size of chunk 400
# Chunk: 7032, size of chunk 400
# Chunk: 7033, size of chunk 400
# Chunk: 7034, size of chunk 400
# Chunk: 7035, size of chunk 400
# Chunk: 7036, size of chunk 400
# Chunk: 7037, size of chunk 400
# Chunk: 7038, size of chunk 400
# Chunk: 7039, size of chunk 400
# Chunk: 7040, size of chunk 400
# Chunk: 7041, size of chunk 400
# Chunk: 7042, size of chunk 400
# Chunk: 7043, size of chunk 400
# Chunk: 7044, size of chunk 400
# Chunk: 7045, size of chunk 400
# Chunk: 7046, size of chunk 400
# Chunk: 7047, size of chunk 400
# Chunk: 7048, size of chunk 400
# Chunk: 7049, size of chunk 400
# Chunk: 7050, size of chunk 400
# Chunk: 7051, size of chunk 400
# Chunk: 7052, size of chunk 400
# Chunk: 7053, size of chunk 400
# Chunk: 7054, size of chunk 400
# Chunk: 7055, size of chunk 400
# Chunk: 7056, size of chunk 400
# Chunk: 7057, size of chunk 400
# Chunk: 7058, size of chunk 400
# Chunk: 7059, size of chunk 400
# Chunk: 7060, size of chunk 400
# Chunk: 7061, size of chunk 400
# Chunk: 7062, size of chunk 400
# Chunk: 7063, size of chunk 400
# Chunk: 7064, size of chunk 400
# Chunk: 7065, size of chunk 400
# Chunk: 7066, size of chunk 400
# Chunk: 7067, size of chunk 400
# Chunk: 7068, size of chunk 400
# Chunk: 7069, size of chunk 400
# Chunk: 7070, size of chunk 400
# Chunk: 7071, size of chunk 400
# Chunk: 7072, size of chunk 400
# Chunk: 7073, size of chunk 400
# Chunk: 7074, size of chunk 400
# Chunk: 7075, size of chunk 400
# Chunk: 7076, size of chunk 400
# Chunk: 7077, size of chunk 400
# Chunk: 7078, size of chunk 400
# Chunk: 7079, size of chunk 400
# Chunk: 7080, size of chunk 400
# Chunk: 7081, size of chunk 400
# Chunk: 7082, size of chunk 400
# Chunk: 7083, size of chunk 400
# Chunk: 7084, size of chunk 400
# Chunk: 7085, size of chunk 400
# Chunk: 7086, size of chunk 400
# Chunk: 7087, size of chunk 400
# Chunk: 7088, size of chunk 400
# Chunk: 7089, size of chunk 400
# Chunk: 7090, size of chunk 400
# Chunk: 7091, size of chunk 400
# Chunk: 7092, size of chunk 400
# Chunk: 7093, size of chunk 400
# Chunk: 7094, size of chunk 400
# Chunk: 7095, size of chunk 400
# Chunk: 7096, size of chunk 400
# Chunk: 7097, size of chunk 400
# Chunk: 7098, size of chunk 400
# Chunk: 7099, size of chunk 400
# Chunk: 7100, size of chunk 400
# Chunk: 7101, size of chunk 400
# Chunk: 7102, size of chunk 400
# Chunk: 7103, size of chunk 400
# Chunk: 7104, size of chunk 400
# Chunk: 7105, size of chunk 400
# Chunk: 7106, size of chunk 400
# Chunk: 7107, size of chunk 400
# Chunk: 7108, size of chunk 400
# Chunk: 7109, size of chunk 400
# Chunk: 7110, size of chunk 400
# Chunk: 7111, size of chunk 400
# Chunk: 7112, size of chunk 400
# Chunk: 7113, size of chunk 400
# Chunk: 7114, size of chunk 400
# Chunk: 7115, size of chunk 400
# Chunk: 7116, size of chunk 400
# Chunk: 7117, size of chunk 400
# Chunk: 7118, size of chunk 400
# Chunk: 7119, size of chunk 400
# Chunk: 7120, size of chunk 400
# Chunk: 7121, size of chunk 400
# Chunk: 7122, size of chunk 400
# Chunk: 7123, size of chunk 400
# Chunk: 7124, size of chunk 400
# Chunk: 7125, size of chunk 400
# Chunk: 7126, size of chunk 400
# Chunk: 7127, size of chunk 400
# Chunk: 7128, size of chunk 400
# Chunk: 7129, size of chunk 400
# Chunk: 7130, size of chunk 400
# Chunk: 7131, size of chunk 400
# Chunk: 7132, size of chunk 400
# Chunk: 7133, size of chunk 400
# Chunk: 7134, size of chunk 400
# Chunk: 7135, size of chunk 400
# Chunk: 7136, size of chunk 400
# Chunk: 7137, size of chunk 400
# Chunk: 7138, size of chunk 400
# Chunk: 7139, size of chunk 400
# Chunk: 7140, size of chunk 400
# Chunk: 7141, size of chunk 400
# Chunk: 7142, size of chunk 400
# Chunk: 7143, size of chunk 400
# Chunk: 7144, size of chunk 400
# Chunk: 7145, size of chunk 400
# Chunk: 7146, size of chunk 400
# Chunk: 7147, size of chunk 400
# Chunk: 7148, size of chunk 400
# Chunk: 7149, size of chunk 400
# Chunk: 7150, size of chunk 400
# Chunk: 7151, size of chunk 400
# Chunk: 7152, size of chunk 400
# Chunk: 7153, size of chunk 400
# Chunk: 7154, size of chunk 400
# Chunk: 7155, size of chunk 400
# Chunk: 7156, size of chunk 400
# Chunk: 7157, size of chunk 400
# Chunk: 7158, size of chunk 400
# Chunk: 7159, size of chunk 400
# Chunk: 7160, size of chunk 400
# Chunk: 7161, size of chunk 400
# Chunk: 7162, size of chunk 400
# Chunk: 7163, size of chunk 400
# Chunk: 7164, size of chunk 400
# Chunk: 7165, size of chunk 400
# Chunk: 7166, size of chunk 400
# Chunk: 7167, size of chunk 400
# Chunk: 7168, size of chunk 400
# Chunk: 7169, size of chunk 400
# Chunk: 7170, size of chunk 400
# Chunk: 7171, size of chunk 400
# Chunk: 7172, size of chunk 400
# Chunk: 7173, size of chunk 400
# Chunk: 7174, size of chunk 400
# Chunk: 7175, size of chunk 400
# Chunk: 7176, size of chunk 400
# Chunk: 7177, size of chunk 400
# Chunk: 7178, size of chunk 400
# Chunk: 7179, size of chunk 400
# Chunk: 7180, size of chunk 400
# Chunk: 7181, size of chunk 400
# Chunk: 7182, size of chunk 400
# Chunk: 7183, size of chunk 400
# Chunk: 7184, size of chunk 400
# Chunk: 7185, size of chunk 400
# Chunk: 7186, size of chunk 400
# Chunk: 7187, size of chunk 400
# Chunk: 7188, size of chunk 400
# Chunk: 7189, size of chunk 400
# Chunk: 7190, size of chunk 400
# Chunk: 7191, size of chunk 400
# Chunk: 7192, size of chunk 400
# Chunk: 7193, size of chunk 400
# Chunk: 7194, size of chunk 400
# Chunk: 7195, size of chunk 400
# Chunk: 7196, size of chunk 400
# Chunk: 7197, size of chunk 400
# Chunk: 7198, size of chunk 400
# Chunk: 7199, size of chunk 400
# Chunk: 7200, size of chunk 400
# Chunk: 7201, size of chunk 400
# Chunk: 7202, size of chunk 400
# Chunk: 7203, size of chunk 400
# Chunk: 7204, size of chunk 400
# Chunk: 7205, size of chunk 400
# Chunk: 7206, size of chunk 400
# Chunk: 7207, size of chunk 400
# Chunk: 7208, size of chunk 400
# Chunk: 7209, size of chunk 400
# Chunk: 7210, size of chunk 400
# Chunk: 7211, size of chunk 400
# Chunk: 7212, size of chunk 400
# Chunk: 7213, size of chunk 400
# Chunk: 7214, size of chunk 400
# Chunk: 7215, size of chunk 400
# Chunk: 7216, size of chunk 400
# Chunk: 7217, size of chunk 400
# Chunk: 7218, size of chunk 400
# Chunk: 7219, size of chunk 400
# Chunk: 7220, size of chunk 400
# Chunk: 7221, size of chunk 400
# Chunk: 7222, size of chunk 400
# Chunk: 7223, size of chunk 400
# Chunk: 7224, size of chunk 400
# Chunk: 7225, size of chunk 400
# Chunk: 7226, size of chunk 400
# Chunk: 7227, size of chunk 400
# Chunk: 7228, size of chunk 400
# Chunk: 7229, size of chunk 400
# Chunk: 7230, size of chunk 400
# Chunk: 7231, size of chunk 400
# Chunk: 7232, size of chunk 400
# Chunk: 7233, size of chunk 400
# Chunk: 7234, size of chunk 400
# Chunk: 7235, size of chunk 400
# Chunk: 7236, size of chunk 400
# Chunk: 7237, size of chunk 400
# Chunk: 7238, size of chunk 400
# Chunk: 7239, size of chunk 400
# Chunk: 7240, size of chunk 400
# Chunk: 7241, size of chunk 400
# Chunk: 7242, size of chunk 400
# Chunk: 7243, size of chunk 400
# Chunk: 7244, size of chunk 400
# Chunk: 7245, size of chunk 400
# Chunk: 7246, size of chunk 400
# Chunk: 7247, size of chunk 400
# Chunk: 7248, size of chunk 400
# Chunk: 7249, size of chunk 400
# Chunk: 7250, size of chunk 400
# Chunk: 7251, size of chunk 400
# Chunk: 7252, size of chunk 400
# Chunk: 7253, size of chunk 400
# Chunk: 7254, size of chunk 400
# Chunk: 7255, size of chunk 400
# Chunk: 7256, size of chunk 400
# Chunk: 7257, size of chunk 400
# Chunk: 7258, size of chunk 400
# Chunk: 7259, size of chunk 400
# Chunk: 7260, size of chunk 400
# Chunk: 7261, size of chunk 400
# Chunk: 7262, size of chunk 400
# Chunk: 7263, size of chunk 400
# Chunk: 7264, size of chunk 400
# Chunk: 7265, size of chunk 400
# Chunk: 7266, size of chunk 400
# Chunk: 7267, size of chunk 400
# Chunk: 7268, size of chunk 400
# Chunk: 7269, size of chunk 400
# Chunk: 7270, size of chunk 400
# Chunk: 7271, size of chunk 400
# Chunk: 7272, size of chunk 400
# Chunk: 7273, size of chunk 400
# Chunk: 7274, size of chunk 400
# Chunk: 7275, size of chunk 400
# Chunk: 7276, size of chunk 400
# Chunk: 7277, size of chunk 400
# Chunk: 7278, size of chunk 400
# Chunk: 7279, size of chunk 400
# Chunk: 7280, size of chunk 400
# Chunk: 7281, size of chunk 400
# Chunk: 7282, size of chunk 400
# Chunk: 7283, size of chunk 400
# Chunk: 7284, size of chunk 400
# Chunk: 7285, size of chunk 400
# Chunk: 7286, size of chunk 400
# Chunk: 7287, size of chunk 400
# Chunk: 7288, size of chunk 400
# Chunk: 7289, size of chunk 400
# Chunk: 7290, size of chunk 400
# Chunk: 7291, size of chunk 400
# Chunk: 7292, size of chunk 400
# Chunk: 7293, size of chunk 400
# Chunk: 7294, size of chunk 400
# Chunk: 7295, size of chunk 400
# Chunk: 7296, size of chunk 400
# Chunk: 7297, size of chunk 400
# Chunk: 7298, size of chunk 400
# Chunk: 7299, size of chunk 400
# Chunk: 7300, size of chunk 400
# Chunk: 7301, size of chunk 400
# Chunk: 7302, size of chunk 400
# Chunk: 7303, size of chunk 400
# Chunk: 7304, size of chunk 400
# Chunk: 7305, size of chunk 400
# Chunk: 7306, size of chunk 400
# Chunk: 7307, size of chunk 400
# Chunk: 7308, size of chunk 400
# Chunk: 7309, size of chunk 400
# Chunk: 7310, size of chunk 400
# Chunk: 7311, size of chunk 400
# Chunk: 7312, size of chunk 400
# Chunk: 7313, size of chunk 400
# Chunk: 7314, size of chunk 400
# Chunk: 7315, size of chunk 400
# Chunk: 7316, size of chunk 400
# Chunk: 7317, size of chunk 400
# Chunk: 7318, size of chunk 400
# Chunk: 7319, size of chunk 400
# Chunk: 7320, size of chunk 400
# Chunk: 7321, size of chunk 400
# Chunk: 7322, size of chunk 400
# Chunk: 7323, size of chunk 400
# Chunk: 7324, size of chunk 400
# Chunk: 7325, size of chunk 400
# Chunk: 7326, size of chunk 400
# Chunk: 7327, size of chunk 400
# Chunk: 7328, size of chunk 400
# Chunk: 7329, size of chunk 400
# Chunk: 7330, size of chunk 400
# Chunk: 7331, size of chunk 400
# Chunk: 7332, size of chunk 400
# Chunk: 7333, size of chunk 400
# Chunk: 7334, size of chunk 400
# Chunk: 7335, size of chunk 400
# Chunk: 7336, size of chunk 400
# Chunk: 7337, size of chunk 400
# Chunk: 7338, size of chunk 400
# Chunk: 7339, size of chunk 400
# Chunk: 7340, size of chunk 400
# Chunk: 7341, size of chunk 400
# Chunk: 7342, size of chunk 400
# Chunk: 7343, size of chunk 400
# Chunk: 7344, size of chunk 400
# Chunk: 7345, size of chunk 400
# Chunk: 7346, size of chunk 400
# Chunk: 7347, size of chunk 400
# Chunk: 7348, size of chunk 400
# Chunk: 7349, size of chunk 400
# Chunk: 7350, size of chunk 400
# Chunk: 7351, size of chunk 400
# Chunk: 7352, size of chunk 400
# Chunk: 7353, size of chunk 400
# Chunk: 7354, size of chunk 400
# Chunk: 7355, size of chunk 400
# Chunk: 7356, size of chunk 400
# Chunk: 7357, size of chunk 400
# Chunk: 7358, size of chunk 400
# Chunk: 7359, size of chunk 400
# Chunk: 7360, size of chunk 400
# Chunk: 7361, size of chunk 400
# Chunk: 7362, size of chunk 400
# Chunk: 7363, size of chunk 400
# Chunk: 7364, size of chunk 400
# Chunk: 7365, size of chunk 400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-c18a68c9f2b4> in <module>
#       5 for i, bookings in enumerate (chunk_bookings):
#       6     print ("Chunk: %d, size of chunk %d"%(i+1, len(bookings)))
# ----> 7     bookings = bookings[bookings['year'] == 2013]
#       8     bookings.drop ('year', axis =1, inplace=True)
#       9     arrival_airports = bookings.groupby ('arr_port')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2891         # Do we have a (boolean) 1d indexer?
#    2892         if com.is_bool_indexer(key):
# -> 2893             return self._getitem_bool_array(key)
#    2894
#    2895         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2945         key = check_bool_indexer(self.index, key)
#    2946         indexer = key.nonzero()[0]
# -> 2947         return self._take_with_is_copy(indexer, axis=0)
#    2948
#    2949     def _getitem_multilevel(self, key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3361         See the docstring of `take` for full explanation of the parameters.
#    3362         """
# -> 3363         result = self.take(indices=indices, axis=axis)
#    3364         # Maybe set copy if we didn't actually change the index.
#    3365         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3348         self._consolidate_inplace()
#    3349
# -> 3350         new_data = self._mgr.take(
#    3351             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3352         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1445
#    1446         new_labels = self.axes[axis].take(indexer)
# -> 1447         return self.reindex_indexer(
#    1448             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1449         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1282             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1283         else:
# -> 1284             new_blocks = [
#    1285                 blk.take_nd(
#    1286                     indexer,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in <listcomp>(.0)
#    1283         else:
#    1284             new_blocks = [
# -> 1285                 blk.take_nd(
#    1286                     indexer,
#    1287                     axis=axis,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1253             allow_fill = True
#    1254
# -> 1255         new_values = algos.take_nd(
#    1256             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1257         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1706             out = np.empty(out_shape, dtype=dtype, order="F")
#    1707         else:
# -> 1708             out = np.empty(out_shape, dtype=dtype)
#    1709
#    1710     func = _get_take_nd_function(
#
# KeyboardInterrupt:

# %%
sum_chunks.head()
# Out:
#           pax
# arr_port
# ACC         6
# ADD         2
# AGP         6
# ALA         2
# ALG         0

# %%
sum_chunks.groupby(sum_chunks.index).pax.sum().sort_values(ascending = False). head(10)
# Out:
# arr_port
# LHR         26173
# MCO         20930
# LAX         20811
# LAS         20443
# JFK         19629
# CDG         19020
# BKK         17517
# MIA         17129
# SFO         17079
# DXB         16366
# Name: pax, dtype: int64

# %%
top10airports = sum_chunks.groupby(sum_chunks.index).pax.sum().sort_values(ascending = False).reset_index()
top10airports
# Out:
#       arr_port    pax
# 0     LHR       26173
# 1     MCO       20930
# 2     LAX       20811
# 3     LAS       20443
# 4     JFK       19629
# ...        ...    ...
# 2269  MYJ         -24
# 2270  UPG         -27
# 2271  XWG         -27
# 2272  MZV        -105
# 2273  AYQ        -381
#
# [2274 rows x 2 columns]

# %% [markdown]
# FINAL RESULT

# %%
chunk_bookings = pd.read_csv('bookings.csv', sep='^', usecols =['arr_port', 'pax', 'year'], chunksize=1000000)
sum_chunks = pd.DataFrame()


for i, bookings in enumerate (chunk_bookings):
    print ("Chunk: %d, size of chunk %d"%(i+1, len(bookings)))
    bookings = bookings[bookings['year'] == 2013]
    bookings.drop ('year', axis =1, inplace=True)
    arrival_airports = bookings.groupby ('arr_port')
    chunk_result = arrival_airports.sum()
    sum_chunks = sum_chunks.append (chunk_result)
top10airports = sum_chunks.groupby(sum_chunks.index).pax.sum().sort_values(ascending = False).reset_index()
# Out:
# Chunk: 1, size of chunk 1000000
# Chunk: 2, size of chunk 1000000
# Chunk: 3, size of chunk 1000000
# Chunk: 4, size of chunk 1000000
# Chunk: 5, size of chunk 1000000
# Chunk: 6, size of chunk 1000000
# /Users/cortinas/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# Chunk: 7, size of chunk 1000000
# Chunk: 8, size of chunk 1000000
# Chunk: 9, size of chunk 1000000
# Chunk: 10, size of chunk 1000000
# Chunk: 11, size of chunk 10

# %%
top10airports.head(10)
# Out:
#    arr_port      pax
# 0  LHR       88809.0
# 1  MCO       70930.0
# 2  LAX       70530.0
# 3  LAS       69630.0
# 4  JFK       66270.0
# 5  CDG       64490.0
# 6  BKK       59460.0
# 7  MIA       58150.0
# 8  SFO       58000.0
# 9  DXB       55590.0

# %%
len(top10airports)
# Out:
# 2274

# %% [markdown]
# BONUS: GET THE NAME OF THE CITY OR AIRPORT CORRESPONDING TO THOSE AIPORTS

# %%
from GeoBases import GeoBase
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-85-247418ef2bc0> in <module>
# ----> 1 from GeoBases import GeoBase
#
# ModuleNotFoundError: No module named 'GeoBases'

# %% [markdown]
# PERSONAL NOTES CHUNKS

# %%
#Chunk notes, only personal notes
data_iterator = pd.read_csv("large_data.csv", chunksize=10**6)



chunk_list = []  



# Each chunk is in dataframe format

for data_chunk in data_iterator:  

  filtered_chunk = chunk_filtering(data_chunk) # own function

  chunk_list.append(filtered_chunk)



filtered_data = pd.concat(chunk_list)
